# %% [markdown]
# <a href="https://colab.research.google.com/github/MA541121/EconomiaIII/blob/main/INFHogar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/canastabasicaTr.csv")

# %%
df2=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/2006_2022_IGRESOTr.csv")

# %%
df3=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/2006_2022GASTOTr.csv")

# %%
df4=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/INPC.csv")

# %%
df5=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/INPC_Maxmin.csv")

# %%
df5
# Out:
#      Año   Max   Min      MesMax     MesMin
# 0   2008  6.53  3.70   Diciembre      Enero
# 1   2009  6.28  3.57       Enero  Diciembre
# 2   2010  4.97  3.64       Marzo      Julio
# 3   2011  3.82  3.04   Diciembre      Marzo
# 4   2012  4.77  3.41  Septiembre      Abril
# 5   2013  4.65  3.25       Abril      Enero
# 6   2014  4.48  3.50       Enero      Abril
# 7   2015  3.14  2.13       Marzo  Diciembre
# 8   2016  3.36  2.54   Diciembre      Junio
# 9   2017  6.77  4.72   Diciembre      Enero
# 10  2018  5.55  4.51       Enero       Mayo
# 11  2019  4.41  2.83       Abril  Diciembre
# 12  2020  4.09  2.15     Octubre      Abril
# 13  2021  7.37  3.54   Noviembre      Enero
# 14  2022  8.70  7.07  Septiembre      Enero
# 15  2023  7.91  4.26       Enero    Octubre
# 16  2024  5.57  4.21       Julio  Diciembre
# 17  2025  3.59  3.77     Febrero      Enero

# %%
df5['volatilidad'] = df5['Max'] - df5['Min']

# %%
df5
# Out:
#      Año   Max   Min      MesMax     MesMin  volatilidad
# 0   2008  6.53  3.70   Diciembre      Enero         2.83
# 1   2009  6.28  3.57       Enero  Diciembre         2.71
# 2   2010  4.97  3.64       Marzo      Julio         1.33
# 3   2011  3.82  3.04   Diciembre      Marzo         0.78
# 4   2012  4.77  3.41  Septiembre      Abril         1.36
# 5   2013  4.65  3.25       Abril      Enero         1.40
# 6   2014  4.48  3.50       Enero      Abril         0.98
# 7   2015  3.14  2.13       Marzo  Diciembre         1.01
# 8   2016  3.36  2.54   Diciembre      Junio         0.82
# 9   2017  6.77  4.72   Diciembre      Enero         2.05
# 10  2018  5.55  4.51       Enero       Mayo         1.04
# 11  2019  4.41  2.83       Abril  Diciembre         1.58
# 12  2020  4.09  2.15     Octubre      Abril         1.94
# 13  2021  7.37  3.54   Noviembre      Enero         3.83
# 14  2022  8.70  7.07  Septiembre      Enero         1.63
# ...

# %%
import plotly.express as px

# %%
fig = px.line(x = df5['Año'], y = df5['volatilidad'], title = 'Volatilidad', template = 'plotly_white')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(x = df5['Año'], y = df5['Min'], title = 'Minimos ', template = 'plotly_white')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(x = df5['Año'], y = df5['Max'], title = 'Maximos ', template = 'plotly_white')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df4.head(12)
# Out:
#     level_0  index   Periodos  Porcentaje Inflación   Año
# 0         0      0 2008-01-01                  3.70  2008
# 1         1      1 2008-02-01                  3.72  2008
# 2         2      2 2008-03-01                  4.25  2008
# 3         3      3 2008-04-01                  4.55  2008
# 4         4      4 2008-05-01                  4.95  2008
# 5         5      5 2008-06-01                  5.26  2008
# 6         6      6 2008-07-01                  5.39  2008
# 7         7      7 2008-08-01                  5.57  2008
# 8         8      8 2008-09-01                  5.47  2008
# 9         9      9 2008-10-01                  5.78  2008
# 10       10     10 2008-11-01                  6.23  2008
# 11       11     11 2008-12-01                  6.53  2008

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Indice Nacional de Precios al Consumidor **

# %%
df4['Año'] = pd.to_datetime(df4['Periodos']).dt.year

# %%
df4
# Out:
#       Periodos  Porcentaje Inflación   Año
# 0   2008-01-01                  3.70  2008
# 1   2008-02-01                  3.72  2008
# 2   2008-03-01                  4.25  2008
# 3   2008-04-01                  4.55  2008
# 4   2008-05-01                  4.95  2008
# ..         ...                   ...   ...
# 201 2024-10-01                  4.76  2024
# 202 2024-11-01                  4.55  2024
# 203 2024-12-01                  4.21  2024
# 204 2025-01-01                  3.59  2025
# 205 2025-02-01                  3.77  2025
#
# [206 rows x 3 columns]

# %%
#df4.sort_index(ascending = True)
df4.sort_values(by = ['Porcentaje Inflación']).iloc[152:155]
# Out:
#       Periodos  Porcentaje Inflación   Año
# 19  2009-08-01                  5.08  2009
# 5   2008-06-01                  5.26  2008
# 121 2018-02-01                  5.34  2018

# %%
df4 = df4.reset_index()
df4
# Out:
#      level_0  index   Periodos  Porcentaje Inflación   Año
# 0          0      0 2008-01-01                  3.70  2008
# 1          1      1 2008-02-01                  3.72  2008
# 2          2      2 2008-03-01                  4.25  2008
# 3          3      3 2008-04-01                  4.55  2008
# 4          4      4 2008-05-01                  4.95  2008
# ..       ...    ...        ...                   ...   ...
# 201      201    201 2024-10-01                  4.76  2024
# 202      202    202 2024-11-01                  4.55  2024
# 203      203    203 2024-12-01                  4.21  2024
# 204      204    204 2025-01-01                  3.59  2025
# 205      205    205 2025-02-01                  3.77  2025
#
# [206 rows x 5 columns]

# %%
plt.figure(figsize=(10,5))
sns.histplot(df4['Porcentaje Inflación'], bins = 10,kde = True, color = 'pink')#bins es anchura de las barras
plt.title('Indice de Precio al consumidor')
plt.xlabel(' Indice base 2da quincena de Julio 2018=100')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x = df4['Porcentaje Inflación'],color = 'darkslateblue')
plt.title('Gráfica de caja INPC')
plt.xlabel(' Porcentaje de Inflación')
plt.ylabel('Frecuencia')
plt.show()

# %%
df4.dropna()
#df4.info()
df4.describe()
# Out:
#        Porcentaje Inflación
# count            206.000000
# mean               4.539078
# std                1.425331
# min                2.130000
# 25%                3.517500
# 50%                4.290000
# 75%                5.320000
# max                8.700000

# %%
import numpy as np

# %% [markdown]
# **Canasta Basica de hogar**
# Gasto Trimestral

# %%
df1
# Out:
#     Año  Gasto Corriente Monetario  Alim,Beb,Tabaco    VC  \
# 0  2006                      29518             8695  1735
# 1  2008                      25711             8674  1354
# 2  2010                      25699             8417  1427
# 3  2012                      25555             8688  1307
# 4  2014                      26467             9031  1240
# 5  2016                      38415            13502  1777
# 6  2018                      39147            13787  1754
# 7  2020                      34108            12977  1018
# 8  2022                      39965            15059  1523
#
#    Vivienda,Combustibles  Artic. Y serv casa  Salud  Transp. Y Comunicaciones  \
# 0                   2624                1881   1204                      5592
# 1                   2572                1541    803                      4733
# 2                   2394                1591    689                      4764
# ...

# %%
corr_matrix = df1[['Gasto Corriente Monetario','Alim,Beb,Tabaco','VC','Vivienda,Combustibles','Artic. Y serv casa','Salud','Transp. Y Comunicaciones','Educacion,Esparcimiento','CP','Tranfer. De gasto']].corr()

# %%
corr_matrix
# Out:
#                            Gasto Corriente Monetario  Alim,Beb,Tabaco  \
# Gasto Corriente Monetario                   1.000000         0.970275
# Alim,Beb,Tabaco                             0.970275         1.000000
# VC                                          0.463978         0.256242
# Vivienda,Combustibles                       0.956218         0.974412
# Artic. Y serv casa                          0.980699         0.962347
# Salud                                       0.717710         0.706154
# Transp. Y Comunicaciones                    0.996730         0.955860
# Educacion,Esparcimiento                     0.446717         0.242380
# CP                                          0.962656         0.981605
# Tranfer. De gasto                           0.620017         0.468243
#
#                                  VC  Vivienda,Combustibles  \
# Gasto Corriente Monetario  0.463978               0.956218
# Alim,Beb,Tabaco            0.256242               0.974412
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(corr_matrix, annot = True,vmin = -1, vmax = 1, cmap = 'coolwarm',linewidths=1)
plt.title('Matriz de correlación')
plt.show()

# %% [markdown]
# **Ingresos por Deciles de Hogar**
# Por Trimestre

# %%
df_2=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/2006_2022INGRESOS.csv")

# %%
df_2
# Out:
#    Deciles de hogares    2006    2008    2010    2012    2014    2016    2018  \
# 0               Total   43698   42865   37574   38125   39719   63565   60916
# 1                   I    7796    7136    6633    6997    7716   11141   11183
# 2                  II   13506   12460   11673   11794   12721   19382   19755
# 3                 III   17780   16792   15611   15734   16677   25811   26288
# 4                  IV   22161   20986   19650   19513   20675   32138   32743
# 5                   V   27072   25628   23973   23914   24901   39311   39640
# 6                  VI   32611   31501   29059   28862   29852   47537   47777
# 7                 VII   40357   39381   35605   35570   36223   57904   57979
# 8                VIII   50788   50084   45089   44849   45478   72868   72239
# 9                  IX   69194   69159   61133   61014   62163   98333   96445
# 10                  X  155715  155525  127313  133003  140783  231226  205106
#
#       2020    2022
# ...

# %%
df_2['2006'].mean()
# Out:
# 43698.0

# %%
media_a_partir_de_fila = df_2['2006'][1:].mean()

print(media_a_partir_de_fila)
# Out:
# 43698.0

# %% [markdown]
# **Gastos Por decil de Hogar**
# de manera Trimestral

# %%
df3
# Out:
#    Deciles de hogares   2006   2008   2010   2012   2014    2016    2018  \
# 0            Nacional  29518  25711  25699  25555  26467   38415   39147
# 1                   I   7073   7863   8084   7857   8005   12426   12338
# 2                  II  10767  11098  10628  10447  11261   17206   17534
# 3                 III  14332  13666  13420  12770  13832   20757   21257
# 4                  IV  16834  16214  15673  15037  16132   24668   25023
# 5                   V  20396  18965  18349  18515  18726   28689   29571
# 6                  VI  23581  22228  20720  20321  21065   32552   33593
# 7                 VII  28082  25168  25197  24641  24696   38660   39253
# 8                VIII  34518  30161  30103  31396  30010   45109   46621
# 9                  IX  45337  40593  40323  38921  39905   58478   59110
# 10                  X  94258  71157  74493  75644  81034  105606  107170
#
#      2020    2022
# 0   34108   39965
# 1   13548   14722
# 2   16913   19219
# ...

# %%
df1.describe()
df2.describe()
# Out:
#                 2006           2008           2010           2012  \
# count      11.000000      11.000000      11.000000      11.000000
# mean    43698.000000   42865.181818   37573.909091   38125.000000
# std     41224.659722   41513.460894   33701.349589   35178.508305
# min      7796.000000    7136.000000    6633.000000    6997.000000
# 25%     19970.500000   18889.000000   17630.500000   17623.500000
# 50%     32611.000000   31501.000000   29059.000000   28862.000000
# 75%     47243.000000   46474.500000   41331.500000   41487.000000
# max    155715.000000  155525.000000  127313.000000  133003.000000
#
#                 2014           2016           2018           2020  \
# count      11.000000      11.000000      11.000000      11.000000
# mean    39718.909091   63565.090909   60915.545455   57370.272727
# std     37049.528816   61152.436489   53829.006360   48678.585789
# min      7716.000000   11141.000000   11183.000000   11333.000000
# ...

# %%
df_1=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Canastabasica.csv")

# %%
df_1
# Out:
#                    Unnamed: 0   2006   2008   2010   2012   2014   2016  \
# 0   Gasto Corriente Monetario  29518  25711  25699  25555  26467  38415
# 1             Alim,Beb,Tabaco   8695   8674   8417   8688   9031  13502
# 2          Vestido y calzado    1735   1354   1427   1307   1240   1777
# 3       Vivienda,Combustibles   2624   2572   2394   2264   2508   3658
# 4          Artic. Y serv casa   1881   1541   1591   1546   1638   2267
# 5                       Salud   1204    803    689    636    654   1037
# 6    Transp. Y Comunicaciones   5592   4733   4764   4720   4971   7427
# 7  Educacion y esparcimirento   4572   3457   3501   3529   3714   4780
# 8        Cuidados personales    1938   1791   2099   1874   1906   2840
# 9           Tranfer. De gasto   1277    787    817    989    806   1127
#
#     2018   2020   2022
# 0  39147  34108  39965
# 1  13787  12977  15059
# 2   1754   1018   1523
# 3   3733   3746   3793
# 4   2297   2233   2432
# 5   1028   1443   1345
# ...

# %%
df_3=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/2006_2022GASTO.csv")

# %%
df_comparar = pd.concat([df_1,df_3])
df_comparar
# Out:
#                     Unnamed: 0   2006   2008   2010   2012   2014    2016  \
# 0    Gasto Corriente Monetario  29518  25711  25699  25555  26467   38415
# 1              Alim,Beb,Tabaco   8695   8674   8417   8688   9031   13502
# 2           Vestido y calzado    1735   1354   1427   1307   1240    1777
# 3        Vivienda,Combustibles   2624   2572   2394   2264   2508    3658
# 4           Artic. Y serv casa   1881   1541   1591   1546   1638    2267
# 5                        Salud   1204    803    689    636    654    1037
# 6     Transp. Y Comunicaciones   5592   4733   4764   4720   4971    7427
# 7   Educacion y esparcimirento   4572   3457   3501   3529   3714    4780
# 8         Cuidados personales    1938   1791   2099   1874   1906    2840
# 9            Tranfer. De gasto   1277    787    817    989    806    1127
# 0                          NaN  29518  25711  25699  25555  26467   38415
# 1                          NaN   7073   7863   8084   7857   8005   12426
# ...

# %%
df_concatena1 = df_3.merge(df_1, left_on = "2008", right_on = "2008",suffixes = ('_1','_3'))

# %%
df_concatena1
# Out:
#   Deciles de hogares  2006_1   2008  2010_1  2012_1  2014_1  2016_1  2018_1  \
# 0           Nacional   29518  25711   25699   25555   26467   38415   39147
#
#    2020_1  2022_1                 Unnamed: 0  2006_3  2010_3  2012_3  2014_3  \
# 0   34108   39965  Gasto Corriente Monetario   29518   25699   25555   26467
#
#    2016_3  2018_3  2020_3  2022_3
# 0   38415   39147   34108   39965

# %%
df_2=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/2006_2022INGRESOS.csv")

# %%
df_2
# Out:
#    Deciles de hogares    2006    2008    2010    2012    2014    2016    2018  \
# 0               Total   43698   42865   37574   38125   39719   63565   60916
# 1                   I    7796    7136    6633    6997    7716   11141   11183
# 2                  II   13506   12460   11673   11794   12721   19382   19755
# 3                 III   17780   16792   15611   15734   16677   25811   26288
# 4                  IV   22161   20986   19650   19513   20675   32138   32743
# 5                   V   27072   25628   23973   23914   24901   39311   39640
# 6                  VI   32611   31501   29059   28862   29852   47537   47777
# 7                 VII   40357   39381   35605   35570   36223   57904   57979
# 8                VIII   50788   50084   45089   44849   45478   72868   72239
# 9                  IX   69194   69159   61133   61014   62163   98333   96445
# 10                  X  155715  155525  127313  133003  140783  231226  205106
#
#       2020    2022
# ...

# %%
df2
# Out:
#     Año  Total      I     II    III     IV      V     VI    VII   VIII  \
# 0  2006  43698   7796  13506  17780  22161  27072  32611  40357  50788
# 1  2008  42865   7136  12460  16792  20986  25628  31501  39381  50084
# 2  2010  37574   6633  11673  15611  19650  23973  29059  35605  45089
# 3  2012  38125   6997  11794  15734  19513  23914  28862  35570  44849
# 4  2014  39719   7716  12721  16677  20675  24901  29852  36223  45478
# 5  2016  63565  11141  19382  25811  32138  39311  47537  57904  72868
# 6  2018  60916  11183  19755  26288  32743  39640  47777  57979  72239
# 7  2020  57370  11333  19229  25400  31426  38050  45737  55501  69103
# 8  2022  63695  13411  22421  29201  35947  43341  51924  62412  76736
#
#        IX       X
# 0   69194  155715
# 1   69159  155525
# 2   61133  127313
# 3   61014  133003
# 4   62163  140783
# 5   98333  231226
# 6   96445  205106
# 7   91726  186198
# 8  100866  200696

# %%
df_concatena2= df_3.merge(df_2, left_on = "2008", right_on = "2008",suffixes = ('_1','_3'))

# %%
df_concatena2
# Out:
# Empty DataFrame
# Columns: [Deciles de hogares_1, 2006_1, 2008, 2010_1, 2012_1, 2014_1, 2016_1, 2018_1, 2020_1, 2022_1, Deciles de hogares_3, 2006_3, 2010_3, 2012_3, 2014_3, 2016_3, 2018_3, 2020_3, 2022_3]
# Index: []

# %%
df_comparar2 = pd.concat([df2,df3])
df_comparar2
# Out:
#     Año    Total      I     II    III     IV      V     VI    VII   VIII  \
# 0  2006  43698.0   7796  13506  17780  22161  27072  32611  40357  50788
# 1  2008  42865.0   7136  12460  16792  20986  25628  31501  39381  50084
# 2  2010  37574.0   6633  11673  15611  19650  23973  29059  35605  45089
# 3  2012  38125.0   6997  11794  15734  19513  23914  28862  35570  44849
# 4  2014  39719.0   7716  12721  16677  20675  24901  29852  36223  45478
# 5  2016  63565.0  11141  19382  25811  32138  39311  47537  57904  72868
# 6  2018  60916.0  11183  19755  26288  32743  39640  47777  57979  72239
# 7  2020  57370.0  11333  19229  25400  31426  38050  45737  55501  69103
# 8  2022  63695.0  13411  22421  29201  35947  43341  51924  62412  76736
# 0  2006      NaN   7073  10767  14332  16834  20396  23581  28082  34518
# 1  2008      NaN   7863  11098  13666  16214  18965  22228  25168  30161
# 2  2010      NaN   8084  10628  13420  15673  18349  20720  25197  30103
# ...

# %%
corr_matrix = df_comparar2[['I','II','III','IV','V','VI','VII','VIII','IX','X']].corr()

# %%
corr_matrix
# Out:
#              I        II       III        IV         V        VI       VII  \
# I     1.000000  0.882050  0.794801  0.731481  0.669817  0.610565  0.550154
# II    0.882050  1.000000  0.985896  0.965265  0.939147  0.909404  0.875197
# III   0.794801  0.985896  1.000000  0.994790  0.982039  0.964726  0.941553
# IV    0.731481  0.965265  0.994790  1.000000  0.995586  0.986162  0.970329
# V     0.669817  0.939147  0.982039  0.995586  1.000000  0.996242  0.987349
# VI    0.610565  0.909404  0.964726  0.986162  0.996242  1.000000  0.996353
# VII   0.550154  0.875197  0.941553  0.970329  0.987349  0.996353  1.000000
# VIII  0.481900  0.833071  0.911109  0.947436  0.971520  0.986564  0.996219
# IX    0.406048  0.783555  0.873135  0.917394  0.947552  0.969789  0.985813
# X     0.219645  0.640161  0.753092  0.812843  0.857804  0.893577  0.923999
#
#           VIII        IX         X
# I     0.481900  0.406048  0.219645
# II    0.833071  0.783555  0.640161
# III   0.911109  0.873135  0.753092
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(corr_matrix, annot = True,vmin = -1, vmax = 1, cmap = 'coolwarm',linewidths=1)
plt.title('Matriz Con Bases Concatenadas de Ingresos y Gastos')
plt.show()

# %%
corr_matrix = df2[['I','II','III','IV','V','VI','VII','VIII','IX','X']].corr()

# %%
corr_matrix
# Out:
#              I        II       III        IV         V        VI       VII  \
# I     1.000000  0.995771  0.992198  0.989600  0.987255  0.984051  0.979225
# II    0.995771  1.000000  0.999286  0.998470  0.997369  0.995659  0.992736
# III   0.992198  0.999286  1.000000  0.999790  0.999267  0.998317  0.996227
# IV    0.989600  0.998470  0.999790  1.000000  0.999734  0.999097  0.997333
# V     0.987255  0.997369  0.999267  0.999734  1.000000  0.999697  0.998471
# VI    0.984051  0.995659  0.998317  0.999097  0.999697  1.000000  0.999447
# VII   0.979225  0.992736  0.996227  0.997333  0.998471  0.999447  1.000000
# VIII  0.972886  0.988571  0.993123  0.994742  0.996484  0.998103  0.999463
# IX    0.964056  0.982038  0.987705  0.989845  0.992234  0.994674  0.997150
# X     0.873895  0.901474  0.911943  0.916667  0.923279  0.928748  0.935833
#
#           VIII        IX         X
# I     0.972886  0.964056  0.873895
# II    0.988571  0.982038  0.901474
# III   0.993123  0.987705  0.911943
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(corr_matrix, annot = True,vmin = -1, vmax = 1, cmap = 'coolwarm',linewidths=1)
plt.title('Matriz de Ingresos')
plt.show()

# %%
corr_matrix = df3[['I','II','III','IV','V','VI','VII','VIII','IX','X']].corr()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(corr_matrix, annot = True,vmin = -1, vmax = 1, cmap = 'coolwarm',linewidths=1)
plt.title('Matriz de Gastos')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
df2
# Out:
#     Año  Total      I     II    III     IV      V     VI    VII   VIII  \
# 0  2006  43698   7796  13506  17780  22161  27072  32611  40357  50788
# 1  2008  42865   7136  12460  16792  20986  25628  31501  39381  50084
# 2  2010  37574   6633  11673  15611  19650  23973  29059  35605  45089
# 3  2012  38125   6997  11794  15734  19513  23914  28862  35570  44849
# 4  2014  39719   7716  12721  16677  20675  24901  29852  36223  45478
# 5  2016  63565  11141  19382  25811  32138  39311  47537  57904  72868
# 6  2018  60916  11183  19755  26288  32743  39640  47777  57979  72239
# 7  2020  57370  11333  19229  25400  31426  38050  45737  55501  69103
# 8  2022  63695  13411  22421  29201  35947  43341  51924  62412  76736
#
#        IX       X
# 0   69194  155715
# 1   69159  155525
# 2   61133  127313
# 3   61014  133003
# 4   62163  140783
# 5   98333  231226
# 6   96445  205106
# 7   91726  186198
# 8  100866  200696

# %%
df3
# Out:
#     Año  Nacional      I     II    III     IV      V     VI    VII   VIII  \
# 0  2006     29518   7073  10767  14332  16834  20396  23581  28082  34518
# 1  2008     25711   7863  11098  13666  16214  18965  22228  25168  30161
# 2  2010     25699   8084  10628  13420  15673  18349  20720  25197  30103
# 3  2012     25555   7857  10447  12770  15037  18515  20321  24641  31396
# 4  2014     26467   8005  11261  13832  16132  18726  21065  24696  30010
# 5  2016     38415  12426  17206  20757  24668  28689  32552  38660  45109
# 6  2018     39147  12338  17534  21257  25023  29571  33593  39253  46621
# 7  2020     34108  13548  16913  20258  23397  26619  30263  34911  40450
# 8  2022     39965  14722  19219  23337  27282  30801  35466  40150  47723
#
#       IX       X
# 0  45337   94258
# 1  40593   71157
# 2  40323   74493
# 3  38921   75644
# 4  39905   81034
# 5  58478  105606
# 6  59110  107170
# 7  50791   83930
# 8  58706  102241

# %%
fig = px.histogram(df3, x = 'Año',y=['I','II','III','IV','V','VI','VII','VIII','IX','X'], nbins = 50 , title = 'Gastos Trimestrales V de hogar', template = 'plotly_white', marginal = 'box')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
